# %%
import pandas as pd

# %%
df = pd.read_csv('customers_data.csv')

# %%
df
# Out:
#     Company_ID          Company_Name  Company_Profit  \
# 0          1.0  Tech  Enterprises  1         80701.0
# 1          2.0   Global  Partners  2         80511.0
# 2          3.0  Quantum Associates 3        110664.0
# 3          4.0       Prime Network 4             NaN
# 4          5.0    Elite  Ventures  5         69427.0
# ..         ...                   ...             ...
# 95        96.0  Dynamic  Network  96        101428.0
# 96        97.0   Quantum Holdings 97         33449.0
# 97        98.0   Pioneer Ventures 98         71095.0
# 98         NaN         Elite Corp 99        107929.0
# 99       100.0  Global Solutions 100             NaN
#
#                                               Address
# 0              EDSA, Barangay 606, Pasig, Philippines
# 1   Commonwealth Ave, Barangay 789, Taguig, Philip...
# 2        Roxas Blvd, Barangay 505, Pasig, Philippines
# 3   Alabang-Zapote Rd, Barangay 202, Taguig, Phili...
# ...

# %%
df.head()
# Out:
#    Company_ID          Company_Name  Company_Profit  \
# 0         1.0  Tech  Enterprises  1         80701.0
# 1         2.0   Global  Partners  2         80511.0
# 2         3.0  Quantum Associates 3        110664.0
# 3         4.0       Prime Network 4             NaN
# 4         5.0    Elite  Ventures  5         69427.0
#
#                                              Address
# 0             EDSA, Barangay 606, Pasig, Philippines
# 1  Commonwealth Ave, Barangay 789, Taguig, Philip...
# 2       Roxas Blvd, Barangay 505, Pasig, Philippines
# 3  Alabang-Zapote Rd, Barangay 202, Taguig, Phili...
# 4    Ayala Avenue, Barangay 101, Makati, Philippines

# %%
df.set_index('Company_Profit', inplace=True)

# %%
df
# Out:
#                         Company_Name  \
# Company_Profit
# 80701.0         Tech  Enterprises  1
# 80511.0          Global  Partners  2
# 110664.0        Quantum Associates 3
# NaN                  Prime Network 4
# 69427.0           Elite  Ventures  5
# ...                              ...
# 101428.0        Dynamic  Network  96
# 33449.0          Quantum Holdings 97
# 71095.0          Pioneer Ventures 98
# 107929.0               Elite Corp 99
# NaN             Global Solutions 100
#
#                                                           Address
# Company_Profit
# 80701.0                    EDSA, Barangay 606, Pasig, Philippines
# 80511.0         Commonwealth Ave, Barangay 789, Taguig, Philip...
# 110664.0             Roxas Blvd, Barangay 505, Pasig, Philippines
# NaN             Alabang-Zapote Rd, Barangay 202, Taguig, Phili...
# 69427.0           Ayala Avenue, Barangay 101, Makati, Philippines
# ...                                                           ...
# ...

# %%
df.isnull().sum()
# Out:
# Company_Name    0
# Address         0
# dtype: int64
