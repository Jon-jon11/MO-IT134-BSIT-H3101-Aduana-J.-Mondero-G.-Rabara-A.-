# %%
import pandas as pd

# %%
customer = pd.read_csv('customers_data.csv')
product = pd.read_csv('products_data.csv')
transaction = pd.read_csv('transactions_data.csv')

# %%
customer
# Out:
#     Company_ID          Company_Name  Company_Profit  \
# 0          1.0  Tech  Enterprises  1         80701.0
# 1          2.0   Global  Partners  2         80511.0
# 2          3.0  Quantum Associates 3        110664.0
# 3          4.0       Prime Network 4             NaN
# 4          5.0    Elite  Ventures  5         69427.0
# ..         ...                   ...             ...
# 95        96.0  Dynamic  Network  96        101428.0
# 96        97.0   Quantum Holdings 97         33449.0
# 97        98.0   Pioneer Ventures 98         71095.0
# 98         NaN         Elite Corp 99        107929.0
# 99       100.0  Global Solutions 100             NaN
#
#                                               Address
# 0              EDSA, Barangay 606, Pasig, Philippines
# 1   Commonwealth Ave, Barangay 789, Taguig, Philip...
# 2        Roxas Blvd, Barangay 505, Pasig, Philippines
# 3   Alabang-Zapote Rd, Barangay 202, Taguig, Phili...
# ...

# %%
product
# Out:
#     Product_ID                  Product_Name Product_Price
# 0          1.0            FinPredictor Suite      ?140,000
# 1          2.0        MarketMinder Analytics      ?168,000
# 2          3.0          TrendWise Forecaster      ?100,800
# 3          4.0        CustomerScope Insights      ?123,200
# 4          5.0           SalesSync Optimizer       ?84,000
# 5          6.0          RevenueVue Dashboard      ?179,200
# 6          7.0   DataBridge Integration Tool      ?151,200
# 7          NaN             RiskRadar Monitor      ?151,200
# 8          9.0                     Product 9      ?112,000
# 9         10.0            SegmentX Targeting       ?89,600
# 10        11.0           OptiFlow Automation      ?156,800
# 11        12.0              BudgetMaster Pro       ?84,000
# 12        13.0           ForecastXcelerator       ?196,000
# 13        14.0  InsightMax Insights Platform      ?128,800
# 14        15.0            NexGen Segmentator      ?100,800
# ...

# %%
transaction
# Out:
#       Unnamed: 0  Transaction_ID  Company_ID  Product_ID  Quantity  \
# 0            0.0             1.0        88.0         6.0       NaN
# 1            1.0             2.0        29.0        19.0      16.0
# 2            2.0             NaN        28.0        18.0       6.0
# 3            3.0             4.0        85.0        12.0      12.0
# 4            4.0             5.0        47.0         3.0       8.0
# ...          ...             ...         ...         ...       ...
# 9995      9995.0             NaN         NaN        10.0       NaN
# 9996      9996.0          9997.0        39.0         2.0       9.0
# 9997      9997.0             NaN        90.0         1.0      15.0
# 9998      9998.0          9999.0        33.0         NaN      19.0
# 9999      9999.0             NaN        77.0        16.0      14.0
#
#      Transaction_Date  Product_Price  Total_Cost
# 0          2024/03/26  194379.147964   1075200.0
# 1       July 09, 2024   97930.993380   1428000.0
# ...

# %%
customer.isnull().sum()
# Out:
# Company_ID        0
# Company_Name      0
# Company_Profit    0
# Address           0
# dtype: int64

# %%
product.isnull().sum()
# Out:
# Product_ID       2
# Product_Name     0
# Product_Price    0
# dtype: int64

# %%
customer
# Out:
#     Company_ID          Company_Name  Company_Profit  \
# 0          1.0  Tech  Enterprises  1         80701.0
# 1          2.0   Global  Partners  2         80511.0
# 2          3.0  Quantum Associates 3        110664.0
# 3          4.0       Prime Network 4             NaN
# 4          5.0    Elite  Ventures  5         69427.0
# ..         ...                   ...             ...
# 95        96.0  Dynamic  Network  96        101428.0
# 96        97.0   Quantum Holdings 97         33449.0
# 97        98.0   Pioneer Ventures 98         71095.0
# 98         NaN         Elite Corp 99        107929.0
# 99       100.0  Global Solutions 100             NaN
#
#                                               Address
# 0              EDSA, Barangay 606, Pasig, Philippines
# 1   Commonwealth Ave, Barangay 789, Taguig, Philip...
# 2        Roxas Blvd, Barangay 505, Pasig, Philippines
# 3   Alabang-Zapote Rd, Barangay 202, Taguig, Phili...
# ...

# %%
customer['Company_ID'] = customer['Company_ID'].fillna(customer['Company_ID'].ffill)
customer['Company_Profit'] = customer['Company_Profit'].fillna(value=customer['Company_Profit'].median())

# %%
customer
# Out:
#                                            Company_ID          Company_Name  \
# 0                                                 1.0  Tech  Enterprises  1
# 1                                                 2.0   Global  Partners  2
# 2                                                 3.0  Quantum Associates 3
# 3                                                 4.0       Prime Network 4
# 4                                                 5.0    Elite  Ventures  5
# ..                                                ...                   ...
# 95                                               96.0  Dynamic  Network  96
# 96                                               97.0   Quantum Holdings 97
# 97                                               98.0   Pioneer Ventures 98
# 98  <bound method NDFrame.ffill of 0       1.0\n1 ...         Elite Corp 99
# 99                                              100.0  Global Solutions 100
#
# ...

# %%
transaction.isnull().sum()
# Out:
# Unnamed: 0          1000
# Transaction_ID      1000
# Company_ID          1000
# Product_ID          1000
# Quantity            1000
# Transaction_Date       0
# Product_Price       1000
# Total_Cost          1000
# dtype: int64

# %%
transaction['Quantity'] = transaction['Quantity'].fillna(value=transaction['Quantity'].median())

# %%
transaction['Total_Cost'] = transaction['Total_Cost'].fillna(value=transaction['Total_Cost'].median())

# %%
transaction
# Out:
#       Unnamed: 0  Transaction_ID  Company_ID  Product_ID  Quantity  \
# 0            0.0             1.0        88.0         6.0      11.0
# 1            1.0             2.0        29.0        19.0      16.0
# 2            2.0             NaN        28.0        18.0       6.0
# 3            3.0             4.0        85.0        12.0      12.0
# 4            4.0             5.0        47.0         3.0       8.0
# ...          ...             ...         ...         ...       ...
# 9995      9995.0             NaN         NaN        10.0      11.0
# 9996      9996.0          9997.0        39.0         2.0       9.0
# 9997      9997.0             NaN        90.0         1.0      15.0
# 9998      9998.0          9999.0        33.0         NaN      19.0
# 9999      9999.0             NaN        77.0        16.0      14.0
#
#      Transaction_Date  Product_Price  Total_Cost
# 0          2024/03/26  194379.147964   1075200.0
# 1       July 09, 2024   97930.993380   1428000.0
# ...

# %%
product['Product_ID'] = product['Product_ID'].fillna(product['Product_ID'].ffill)

# %%
product
# Out:
#                                            Product_ID  \
# 0                                                 1.0
# 1                                                 2.0
# 2                                                 3.0
# 3                                                 4.0
# 4                                                 5.0
# 5                                                 6.0
# 6                                                 7.0
# 7   <bound method NDFrame.ffill of 0      1.0\n1  ...
# 8                                                 9.0
# 9                                                10.0
# 10                                               11.0
# 11                                               12.0
# 12                                               13.0
# 13                                               14.0
# 14                                               15.0
# 15  <bound method NDFrame.ffill of 0      1.0\n1  ...
# ...
